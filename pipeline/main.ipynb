# %%
import cv2
import numpy as np
import supervision as sv
from ultralytics import YOLO

# %%
road_detect_model_path = "models/yolo-road_object_detect_model/best.pt"
road_detect_model = YOLO(road_detect_model_path)
print("Road Object Detection Model Loaded ... ")
# Out:
# Road Object Detection Model Loaded ...

# %%
from segment_anything import SamPredictor, sam_model_registry
model_type = "vit_h"
device = "mps"
sam = sam_model_registry[model_type](checkpoint="models/sam_segment_model/sam_vit_h_4b8939.pth")
sam.to(device=device)
predictor = SamPredictor(sam)
print("Sam model loaded")
# Out:
# Sam model loaded

# %%
def road_object_detection(frame, model):
    results = model(frame, device="mps", conf=0.5)[0]
    results = results.boxes.data.tolist()
    bounding_box = []
    if len(results) > 0:
        for i in results:
            x1, y1, x2, y2, _, class_id = i
            bounding_box.append([x1, y1, x2, y2])
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
    return bounding_box, frame

# %%
def sam_model(image, road_bounding_box):
    for i in range(len(road_bounding_box)):
        temp = road_bounding_box[i]
        box = np.array([temp[0], temp[1], temp[2], temp[3]])
        predictor.set_image(image)   
        masks, scores, logits = predictor.predict(
            box=box,
            multimask_output=True
        )
        box_annotator = sv.BoxAnnotator(color=sv.Color.green())
        mask_annotator = sv.MaskAnnotator(color=sv.Color.green(),color_lookup=sv.ColorLookup.INDEX)
        detections = sv.Detections(
            xyxy=sv.mask_to_xyxy(masks=masks),
            mask=masks
        )
        segmented_image = mask_annotator.annotate(scene=image, detections=detections)
        return segmented_image

# %%
def extract_and_process(input_video_key, output_video_key):
    cap = cv2.VideoCapture(input_video_key)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    frame_rate = int(cap.get(cv2.CAP_PROP_FPS))
    
    out = cv2.VideoWriter(output_video_key, cv2.VideoWriter_fourcc(*'MP4V'), frame_rate, (frame_width, frame_height), isColor=True)
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        road_bounding_box, image = road_object_detection(frame, road_detect_model)
        if len(road_bounding_box):
            segmented_image = sam_model(frame, road_bounding_box)
        else:
            segmented_image = frame
        
        out.write(segmented_image)
    
    cap.release()
    out.release()

# %%
if __name__ == "__main__":
    input_video_key = 'input/sample.mp4'
    output_video_key = 'output/processed_output.mp4'
    extract_and_process(input_video_key, output_video_key)
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 0: 384x640 1 road, 250.2ms
# Speed: 10.4ms preprocess, 250.2ms inference, 120.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 33.6ms
# Speed: 1.8ms preprocess, 33.6ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.8ms
# Speed: 2.3ms preprocess, 19.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.6ms
# Speed: 2.3ms preprocess, 19.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.6ms
# Speed: 2.0ms preprocess, 19.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 24.7ms
# Speed: 2.4ms preprocess, 24.7ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.2ms
# Speed: 1.8ms preprocess, 19.2ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.7ms
# Speed: 2.1ms preprocess, 20.7ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 25.7ms
# Speed: 2.8ms preprocess, 25.7ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 roads, 19.5ms
# Speed: 2.1ms preprocess, 19.5ms inference, 61.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.6ms
# Speed: 2.0ms preprocess, 19.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.7ms
# Speed: 1.9ms preprocess, 20.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.7ms
# Speed: 2.1ms preprocess, 19.7ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.9ms
# Speed: 1.8ms preprocess, 18.9ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.9ms
# Speed: 1.8ms preprocess, 18.9ms inference, 44.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 22.2ms
# Speed: 2.5ms preprocess, 22.2ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.8ms
# Speed: 2.9ms preprocess, 18.8ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.7ms
# Speed: 2.1ms preprocess, 19.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.8ms
# Speed: 2.4ms preprocess, 18.8ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 23.4ms
# Speed: 2.1ms preprocess, 23.4ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.7ms
# Speed: 1.8ms preprocess, 19.7ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.2ms
# Speed: 1.8ms preprocess, 18.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.7ms
# Speed: 1.9ms preprocess, 19.7ms inference, 50.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.5ms
# Speed: 2.0ms preprocess, 19.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.7ms
# Speed: 3.1ms preprocess, 19.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.6ms
# Speed: 1.9ms preprocess, 19.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 21.5ms
# Speed: 2.3ms preprocess, 21.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.9ms
# Speed: 2.3ms preprocess, 18.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.8ms
# Speed: 1.8ms preprocess, 19.8ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.5ms
# Speed: 2.1ms preprocess, 19.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.0ms
# Speed: 2.1ms preprocess, 19.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 24.6ms
# Speed: 2.1ms preprocess, 24.6ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.7ms
# Speed: 2.3ms preprocess, 19.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.4ms
# Speed: 2.4ms preprocess, 20.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.1ms
# Speed: 2.2ms preprocess, 19.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.4ms
# Speed: 2.1ms preprocess, 19.4ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.0ms
# Speed: 2.3ms preprocess, 20.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 21.1ms
# Speed: 2.3ms preprocess, 21.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.5ms
# Speed: 2.5ms preprocess, 19.5ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.1ms
# Speed: 2.4ms preprocess, 20.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.2ms
# Speed: 1.8ms preprocess, 18.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.9ms
# Speed: 1.9ms preprocess, 18.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.3ms
# Speed: 1.8ms preprocess, 19.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.0ms
# Speed: 2.5ms preprocess, 20.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.8ms
# Speed: 3.4ms preprocess, 20.8ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.9ms
# Speed: 2.1ms preprocess, 19.9ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.2ms
# Speed: 2.4ms preprocess, 19.2ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 36.9ms
# Speed: 3.8ms preprocess, 36.9ms inference, 14.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 34.7ms
# Speed: 4.3ms preprocess, 34.7ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 28.2ms
# Speed: 3.8ms preprocess, 28.2ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.1ms
# Speed: 1.9ms preprocess, 19.1ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 24.6ms
# Speed: 2.4ms preprocess, 24.6ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.1ms
# Speed: 1.9ms preprocess, 19.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.6ms
# Speed: 2.1ms preprocess, 18.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.5ms
# Speed: 5.0ms preprocess, 20.5ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.3ms
# Speed: 1.8ms preprocess, 18.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.1ms
# Speed: 1.8ms preprocess, 19.1ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.9ms
# Speed: 1.7ms preprocess, 18.9ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 26.0ms
# Speed: 2.7ms preprocess, 26.0ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.5ms
# Speed: 2.1ms preprocess, 20.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 23.8ms
# Speed: 2.7ms preprocess, 23.8ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.2ms
# Speed: 1.9ms preprocess, 18.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.5ms
# Speed: 1.9ms preprocess, 18.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.1ms
# Speed: 2.4ms preprocess, 19.1ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.2ms
# Speed: 2.2ms preprocess, 18.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 29.1ms
# Speed: 3.3ms preprocess, 29.1ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 23.0ms
# Speed: 2.1ms preprocess, 23.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 44.3ms
# Speed: 2.6ms preprocess, 44.3ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 26.6ms
# Speed: 3.3ms preprocess, 26.6ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 23.0ms
# Speed: 2.4ms preprocess, 23.0ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 55.6ms
# Speed: 3.7ms preprocess, 55.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.9ms
# Speed: 2.6ms preprocess, 19.9ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.5ms
# Speed: 1.8ms preprocess, 19.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.2ms
# Speed: 2.6ms preprocess, 18.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.9ms
# Speed: 2.3ms preprocess, 19.9ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.2ms
# Speed: 1.8ms preprocess, 18.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 36.1ms
# Speed: 3.3ms preprocess, 36.1ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.3ms
# Speed: 3.4ms preprocess, 20.3ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 26.6ms
# Speed: 2.4ms preprocess, 26.6ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.5ms
# Speed: 1.8ms preprocess, 18.5ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.5ms
# Speed: 1.9ms preprocess, 19.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.2ms
# Speed: 1.9ms preprocess, 20.2ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 22.7ms
# Speed: 2.3ms preprocess, 22.7ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 25.9ms
# Speed: 2.6ms preprocess, 25.9ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 23.1ms
# Speed: 2.7ms preprocess, 23.1ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 23.9ms
# Speed: 3.0ms preprocess, 23.9ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.2ms
# Speed: 2.6ms preprocess, 20.2ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.1ms
# Speed: 2.4ms preprocess, 19.1ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 23.1ms
# Speed: 3.3ms preprocess, 23.1ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 27.7ms
# Speed: 3.3ms preprocess, 27.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 31.5ms
# Speed: 3.5ms preprocess, 31.5ms inference, 10.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 22.8ms
# Speed: 2.4ms preprocess, 22.8ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.3ms
# Speed: 2.2ms preprocess, 19.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.6ms
# Speed: 2.1ms preprocess, 19.6ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 42.6ms
# Speed: 2.4ms preprocess, 42.6ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 26.0ms
# Speed: 2.3ms preprocess, 26.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 23.5ms
# Speed: 3.7ms preprocess, 23.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 27.2ms
# Speed: 3.1ms preprocess, 27.2ms inference, 16.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 26.1ms
# Speed: 2.2ms preprocess, 26.1ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.6ms
# Speed: 2.1ms preprocess, 20.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.4ms
# Speed: 2.1ms preprocess, 17.4ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.2ms
# Speed: 1.9ms preprocess, 17.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.2ms
# Speed: 1.6ms preprocess, 19.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.5ms
# Speed: 1.9ms preprocess, 18.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.8ms
# Speed: 2.4ms preprocess, 17.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.5ms
# Speed: 1.8ms preprocess, 20.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 24.0ms
# Speed: 2.2ms preprocess, 24.0ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.6ms
# Speed: 1.6ms preprocess, 17.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.2ms
# Speed: 2.3ms preprocess, 18.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.1ms
# Speed: 1.6ms preprocess, 18.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.0ms
# Speed: 2.4ms preprocess, 18.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 21.7ms
# Speed: 2.5ms preprocess, 21.7ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.0ms
# Speed: 1.6ms preprocess, 18.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.9ms
# Speed: 2.1ms preprocess, 18.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 27.8ms
# Speed: 2.1ms preprocess, 27.8ms inference, 13.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.8ms
# Speed: 2.1ms preprocess, 18.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.3ms
# Speed: 2.1ms preprocess, 18.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.0ms
# Speed: 2.9ms preprocess, 19.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.2ms
# Speed: 1.9ms preprocess, 18.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 24.4ms
# Speed: 2.7ms preprocess, 24.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 17.5ms
# Speed: 2.4ms preprocess, 17.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.8ms
# Speed: 2.4ms preprocess, 19.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 19.1ms
# Speed: 1.5ms preprocess, 19.1ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 road, 21.2ms
# Speed: 2.4ms preprocess, 21.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
